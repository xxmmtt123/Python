# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('result_copy.csv')
df
# Out:
#             volume       Per5d  VOLUME_SENTIMENT_7DAY  SENTIMENT_SCORE_7DAY  \
# 0       28346286.0  140.420372                   13.0                0.4004
# 1        9660547.0  122.127660                   14.0                0.1638
# 2        1537762.0  102.437870                    9.0                0.0596
# 3       21631003.0   71.088861                   27.0               -0.1304
# 4        1044615.0   69.957983                    2.0                0.2500
# ...            ...         ...                    ...                   ...
# 407970  15241179.0         NaN                   65.0                0.0605
# 407971  15237174.0         NaN                   35.0                0.1485
# 407972   2123013.0         NaN                   11.0                0.0468
# 407973   1046340.0         NaN                    5.0                0.2001
# 407974         NaN         NaN                    NaN                   NaN
#
#         VOLUME_SENTIMENT_30DAY  SENTIMENT_SCORE_30DAY  portfolio  \
# 0                         58.0                 0.2492  Russell 1
# 1                         45.0                 0.1757  Russell 1
# 2                         52.0                 0.2129  Russell 1
# 3                         58.0                -0.2655  Russell 1
# 4                          4.0                 0.1583  Russell 1
# ...                        ...                    ...        ...
# 407970                   484.0                 0.1587  Russell 1
# 407971                    95.0                 0.1341  Russell 1
# 407972                   143.0                 0.1300  Russell 1
# 407973                    31.0                 0.2104  Russell 1
# 407974                     NaN                    NaN        NaN
#
#                      sector MarketcapValue  Consecutive_Sentiment_Score  \
# 0         Consumer Services        Mid Cap                            0
# 1         Health Technology      Large Cap                            0
# 2         Health Technology      Large Cap                            2
# 3                 Utilities      Large Cap                            0
# 4         Health Technology        Mid Cap                            0
# ...                     ...            ...                          ...
# 407970  Technology Services      Large Cap                            0
# 407971  Technology Services        Mid Cap                            0
# 407972  Technology Services      Large Cap                            0
# 407973    Health Technology      Large Cap                            0
# 407974                  NaN            NaN                            0
#
#          VIX Adj Close   VIX %_Change
# 0             24.459999         -0.05
# 1             46.799999         -0.08
# 2             26.870001         -0.10
# 3             19.520000         -0.06
# 4             15.000000         -0.08
# ...                 ...           ...
# 407970        26.270000          0.00
# 407971        26.270000          0.00
# 407972        26.270000          0.00
# 407973        26.270000          0.00
# 407974              NaN           NaN
#
# [407975 rows x 12 columns]

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# **Cleaning missing values**

# %%
df = df[df['VIX %_Change'].notna()]

# %%
df = df[df['Per5d'].notna()]
df
# Out:
#             volume       Per5d  VOLUME_SENTIMENT_7DAY  SENTIMENT_SCORE_7DAY  \
# 0       28346286.0  140.420372                   13.0                0.4004
# 1        9660547.0  122.127660                   14.0                0.1638
# 2        1537762.0  102.437870                    9.0                0.0596
# 3       21631003.0   71.088861                   27.0               -0.1304
# 4        1044615.0   69.957983                    2.0                0.2500
# ...            ...         ...                    ...                   ...
# 406936  38969055.0  -46.909903                   48.0               -0.1059
# 406937  10198118.0  -61.014493                    3.0               -0.0987
# 406938    487894.0  -53.977615                   11.0                0.1218
# 406939   1507414.0  -61.394558                    4.0                0.2904
# 406940   1622428.0  -66.905482                    4.0                0.3056
#
#         VOLUME_SENTIMENT_30DAY  SENTIMENT_SCORE_30DAY  portfolio  \
# 0                         58.0                 0.2492  Russell 1
# 1                         45.0                 0.1757  Russell 1
# 2                         52.0                 0.2129  Russell 1
# 3                         58.0                -0.2655  Russell 1
# 4                          4.0                 0.1583  Russell 1
# ...                        ...                    ...        ...
# 406936                   143.0                 0.0234  Russell 1
# 406937                    44.0                 0.1727  Russell 1
# 406938                    65.0                 0.1538  Russell 1
# 406939                    28.0                 0.1783  Russell 1
# 406940                    21.0                 0.1637  Russell 1
#
#                      sector MarketcapValue  Consecutive_Sentiment_Score  \
# 0         Consumer Services        Mid Cap                            0
# 1         Health Technology      Large Cap                            0
# 2         Health Technology      Large Cap                            2
# 3                 Utilities      Large Cap                            0
# 4         Health Technology        Mid Cap                            0
# ...                     ...            ...                          ...
# 406936      Energy Minerals      Large Cap                            0
# 406937      Energy Minerals        Mid Cap                            0
# 406938    Health Technology        Mid Cap                            0
# 406939  Technology Services        Mid Cap                            0
# 406940    Health Technology      Large Cap                            0
#
#          VIX Adj Close   VIX %_Change
# 0             24.459999         -0.05
# 1             46.799999         -0.08
# 2             26.870001         -0.10
# 3             19.520000         -0.06
# 4             15.000000         -0.08
# ...                 ...           ...
# 406936        41.940000          0.06
# 406937        41.940000          0.06
# 406938        14.800000         -0.07
# 406939        30.430000         -0.04
# 406940        27.510000         -0.04
#
# [399765 rows x 12 columns]

# %% [markdown]
# **Label target values**

# %%
def label_Per5d(row):
    if row['Per5d'] >= 0:
        return '1'
    if row['Per5d'] < 0:
        return '0'

# %%
df['Per5d_labeled'] = df.apply(lambda row: label_Per5d(row), axis=1)
df
# Out:
#             volume       Per5d  VOLUME_SENTIMENT_7DAY  SENTIMENT_SCORE_7DAY  \
# 0       28346286.0  140.420372                   13.0                0.4004
# 1        9660547.0  122.127660                   14.0                0.1638
# 2        1537762.0  102.437870                    9.0                0.0596
# 3       21631003.0   71.088861                   27.0               -0.1304
# 4        1044615.0   69.957983                    2.0                0.2500
# ...            ...         ...                    ...                   ...
# 406936  38969055.0  -46.909903                   48.0               -0.1059
# 406937  10198118.0  -61.014493                    3.0               -0.0987
# 406938    487894.0  -53.977615                   11.0                0.1218
# 406939   1507414.0  -61.394558                    4.0                0.2904
# 406940   1622428.0  -66.905482                    4.0                0.3056
#
#         VOLUME_SENTIMENT_30DAY  SENTIMENT_SCORE_30DAY  portfolio  \
# 0                         58.0                 0.2492  Russell 1
# 1                         45.0                 0.1757  Russell 1
# 2                         52.0                 0.2129  Russell 1
# 3                         58.0                -0.2655  Russell 1
# 4                          4.0                 0.1583  Russell 1
# ...                        ...                    ...        ...
# 406936                   143.0                 0.0234  Russell 1
# 406937                    44.0                 0.1727  Russell 1
# 406938                    65.0                 0.1538  Russell 1
# 406939                    28.0                 0.1783  Russell 1
# 406940                    21.0                 0.1637  Russell 1
#
#                      sector MarketcapValue  Consecutive_Sentiment_Score  \
# 0         Consumer Services        Mid Cap                            0
# 1         Health Technology      Large Cap                            0
# 2         Health Technology      Large Cap                            2
# 3                 Utilities      Large Cap                            0
# 4         Health Technology        Mid Cap                            0
# ...                     ...            ...                          ...
# 406936      Energy Minerals      Large Cap                            0
# 406937      Energy Minerals        Mid Cap                            0
# 406938    Health Technology        Mid Cap                            0
# 406939  Technology Services        Mid Cap                            0
# 406940    Health Technology      Large Cap                            0
#
#          VIX Adj Close   VIX %_Change Per5d_labeled
# 0             24.459999         -0.05             1
# 1             46.799999         -0.08             1
# 2             26.870001         -0.10             1
# 3             19.520000         -0.06             1
# 4             15.000000         -0.08             1
# ...                 ...           ...           ...
# 406936        41.940000          0.06             0
# 406937        41.940000          0.06             0
# 406938        14.800000         -0.07             0
# 406939        30.430000         -0.04             0
# 406940        27.510000         -0.04             0
#
# [399765 rows x 13 columns]

# %% [markdown]
# **Drop selected rows**

# %%
df.drop(df[df.portfolio == 'SCG'].index)
df
# Out:
#             volume       Per5d  VOLUME_SENTIMENT_7DAY  SENTIMENT_SCORE_7DAY  \
# 0       28346286.0  140.420372                   13.0                0.4004
# 1        9660547.0  122.127660                   14.0                0.1638
# 2        1537762.0  102.437870                    9.0                0.0596
# 3       21631003.0   71.088861                   27.0               -0.1304
# 4        1044615.0   69.957983                    2.0                0.2500
# ...            ...         ...                    ...                   ...
# 406936  38969055.0  -46.909903                   48.0               -0.1059
# 406937  10198118.0  -61.014493                    3.0               -0.0987
# 406938    487894.0  -53.977615                   11.0                0.1218
# 406939   1507414.0  -61.394558                    4.0                0.2904
# 406940   1622428.0  -66.905482                    4.0                0.3056
#
#         VOLUME_SENTIMENT_30DAY  SENTIMENT_SCORE_30DAY  portfolio  \
# 0                         58.0                 0.2492  Russell 1
# 1                         45.0                 0.1757  Russell 1
# 2                         52.0                 0.2129  Russell 1
# 3                         58.0                -0.2655  Russell 1
# 4                          4.0                 0.1583  Russell 1
# ...                        ...                    ...        ...
# 406936                   143.0                 0.0234  Russell 1
# 406937                    44.0                 0.1727  Russell 1
# 406938                    65.0                 0.1538  Russell 1
# 406939                    28.0                 0.1783  Russell 1
# 406940                    21.0                 0.1637  Russell 1
#
#                      sector MarketcapValue  Consecutive_Sentiment_Score  \
# 0         Consumer Services        Mid Cap                            0
# 1         Health Technology      Large Cap                            0
# 2         Health Technology      Large Cap                            2
# 3                 Utilities      Large Cap                            0
# 4         Health Technology        Mid Cap                            0
# ...                     ...            ...                          ...
# 406936      Energy Minerals      Large Cap                            0
# 406937      Energy Minerals        Mid Cap                            0
# 406938    Health Technology        Mid Cap                            0
# 406939  Technology Services        Mid Cap                            0
# 406940    Health Technology      Large Cap                            0
#
#          VIX Adj Close   VIX %_Change Per5d_labeled
# 0             24.459999         -0.05             1
# 1             46.799999         -0.08             1
# 2             26.870001         -0.10             1
# 3             19.520000         -0.06             1
# 4             15.000000         -0.08             1
# ...                 ...           ...           ...
# 406936        41.940000          0.06             0
# 406937        41.940000          0.06             0
# 406938        14.800000         -0.07             0
# 406939        30.430000         -0.04             0
# 406940        27.510000         -0.04             0
#
# [399765 rows x 13 columns]

# %% [markdown]
# **Categorical encoding using Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
le_sector = LabelEncoder()
le_MarketcapValue = LabelEncoder()

# %%
df['sector'] = le_sector.fit_transform(df['sector'])
df['MarketcapValue'] = le_MarketcapValue.fit_transform(df['MarketcapValue'])

# %%
df
# Out:
#             volume       Per5d  VOLUME_SENTIMENT_7DAY  SENTIMENT_SCORE_7DAY  \
# 0       28346286.0  140.420372                   13.0                0.4004
# 1        9660547.0  122.127660                   14.0                0.1638
# 2        1537762.0  102.437870                    9.0                0.0596
# 3       21631003.0   71.088861                   27.0               -0.1304
# 4        1044615.0   69.957983                    2.0                0.2500
# ...            ...         ...                    ...                   ...
# 406936  38969055.0  -46.909903                   48.0               -0.1059
# 406937  10198118.0  -61.014493                    3.0               -0.0987
# 406938    487894.0  -53.977615                   11.0                0.1218
# 406939   1507414.0  -61.394558                    4.0                0.2904
# 406940   1622428.0  -66.905482                    4.0                0.3056
#
#         VOLUME_SENTIMENT_30DAY  SENTIMENT_SCORE_30DAY  portfolio  sector  \
# 0                         58.0                 0.2492  Russell 1       4
# 1                         45.0                 0.1757  Russell 1      10
# 2                         52.0                 0.2129  Russell 1      10
# 3                         58.0                -0.2655  Russell 1      18
# 4                          4.0                 0.1583  Russell 1      10
# ...                        ...                    ...        ...     ...
# 406936                   143.0                 0.0234  Russell 1       7
# 406937                    44.0                 0.1727  Russell 1       7
# 406938                    65.0                 0.1538  Russell 1      10
# 406939                    28.0                 0.1783  Russell 1      16
# 406940                    21.0                 0.1637  Russell 1      10
#
#         MarketcapValue  Consecutive_Sentiment_Score   VIX Adj Close   \
# 0                    3                            0        24.459999
# 1                    0                            0        46.799999
# 2                    0                            2        26.870001
# 3                    0                            0        19.520000
# 4                    3                            0        15.000000
# ...                ...                          ...              ...
# 406936               0                            0        41.940000
# 406937               3                            0        41.940000
# 406938               3                            0        14.800000
# 406939               3                            0        30.430000
# 406940               0                            0        27.510000
#
#         VIX %_Change Per5d_labeled
# 0              -0.05             1
# 1              -0.08             1
# 2              -0.10             1
# 3              -0.06             1
# 4              -0.08             1
# ...              ...           ...
# 406936          0.06             0
# 406937          0.06             0
# 406938         -0.07             0
# 406939         -0.04             0
# 406940         -0.04             0
#
# [399765 rows x 13 columns]

# %% [markdown]
# ## 2. Modeling

# %%
inputs = df.drop('Per5d',axis='columns')
inputs = inputs.drop('portfolio',axis='columns')
inputs = inputs.drop('Per5d_labeled',axis='columns')

# %%
inputs
# Out:
#             volume  VOLUME_SENTIMENT_7DAY  SENTIMENT_SCORE_7DAY  \
# 0       28346286.0                   13.0                0.4004
# 1        9660547.0                   14.0                0.1638
# 2        1537762.0                    9.0                0.0596
# 3       21631003.0                   27.0               -0.1304
# 4        1044615.0                    2.0                0.2500
# ...            ...                    ...                   ...
# 406936  38969055.0                   48.0               -0.1059
# 406937  10198118.0                    3.0               -0.0987
# 406938    487894.0                   11.0                0.1218
# 406939   1507414.0                    4.0                0.2904
# 406940   1622428.0                    4.0                0.3056
#
#         VOLUME_SENTIMENT_30DAY  SENTIMENT_SCORE_30DAY  sector  MarketcapValue  \
# 0                         58.0                 0.2492       4               3
# 1                         45.0                 0.1757      10               0
# 2                         52.0                 0.2129      10               0
# 3                         58.0                -0.2655      18               0
# 4                          4.0                 0.1583      10               3
# ...                        ...                    ...     ...             ...
# 406936                   143.0                 0.0234       7               0
# 406937                    44.0                 0.1727       7               3
# 406938                    65.0                 0.1538      10               3
# 406939                    28.0                 0.1783      16               3
# 406940                    21.0                 0.1637      10               0
#
#         Consecutive_Sentiment_Score   VIX Adj Close   VIX %_Change
# 0                                 0        24.459999         -0.05
# 1                                 0        46.799999         -0.08
# 2                                 2        26.870001         -0.10
# 3                                 0        19.520000         -0.06
# 4                                 0        15.000000         -0.08
# ...                             ...              ...           ...
# 406936                            0        41.940000          0.06
# 406937                            0        41.940000          0.06
# 406938                            0        14.800000         -0.07
# 406939                            0        30.430000         -0.04
# 406940                            0        27.510000         -0.04
#
# [399765 rows x 10 columns]

# %%
target = df['Per5d_labeled']
target
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 406936    0
# 406937    0
# 406938    0
# 406939    0
# 406940    0
# Name: Per5d_labeled, Length: 399765, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, y_train)

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y_test, y_predicted)
cm

# %%
print(classification_report(y_test, y_predicted))

# %%
model.feature_importances_

# %%
feature_scores = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_scores, y=feature_scores.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
